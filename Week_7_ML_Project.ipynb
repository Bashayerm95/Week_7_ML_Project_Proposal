# %%
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from yellowbrick.datasets import load_credit
from yellowbrick.features import PCA

# %%
df=pd.read_csv("lending_club_loan_two.csv")

# %%
df = df.dropna()
df
# Out:
#         loan_amnt  ...                                            address
# 0         10000.0  ...     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1          8000.0  ...  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2         15600.0  ...  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3          7200.0  ...            823 Reid Ford\r\nDelacruzside, MA 00813
# 4         24375.0  ...             679 Luna Roads\r\nGreggshire, VA 11650
# ...           ...  ...                                                ...
# 103428    32000.0  ...  6143 Francis Light Suite 139\r\nPort Paul, WA ...
# 103429    16000.0  ...   4647 Chandler Fort\r\nNorth Bryanburgh, VT 30723
# 103430     7925.0  ...   96779 Gabrielle Overpass\r\nTimothyton, ID 70466
# 103431    12000.0  ...  641 Schwartz Forge\r\nWest Stefanieberg, LA 30723
# 103432    10000.0  ...  134 Wilson Trafficway\r\nNew Kimberlyton, OH 0...
#
# [87833 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87833 entries, 0 to 103432
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             87833 non-null  float64
#  1   term                  87833 non-null  object
#  2   int_rate              87833 non-null  float64
#  3   installment           87833 non-null  float64
#  4   grade                 87833 non-null  object
#  5   sub_grade             87833 non-null  object
#  6   emp_title             87833 non-null  object
#  7   emp_length            87833 non-null  object
#  8   home_ownership        87833 non-null  object
#  9   annual_inc            87833 non-null  float64
#  10  verification_status   87833 non-null  object
#  11  issue_d               87833 non-null  object
#  12  loan_status           87833 non-null  object
#  13  purpose               87833 non-null  object
#  14  title                 87833 non-null  object
#  15  dti                   87833 non-null  float64
#  16  earliest_cr_line      87833 non-null  object
#  17  open_acc              87833 non-null  float64
#  18  pub_rec               87833 non-null  float64
#  19  revol_bal             87833 non-null  float64
#  20  revol_util            87833 non-null  float64
#  21  total_acc             87833 non-null  float64
#  22  initial_list_status   87833 non-null  object
#  23  application_type      87833 non-null  object
#  24  mort_acc              87833 non-null  float64
#  25  pub_rec_bankruptcies  87833 non-null  float64
#  26  address               87833 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 18.8+ MB

# %%
df2 = df.copy()

# %%
df2.drop(columns = ['emp_title','home_ownership','title','earliest_cr_line','grade', 'address','purpose'],inplace=True)
df2
# Out:
#         loan_amnt        term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0   36 months  ...       0.0                   0.0
# 1          8000.0   36 months  ...       3.0                   0.0
# 2         15600.0   36 months  ...       0.0                   0.0
# 3          7200.0   36 months  ...       0.0                   0.0
# 4         24375.0   60 months  ...       1.0                   0.0
# ...           ...         ...  ...       ...                   ...
# 103428    32000.0   36 months  ...       2.0                   0.0
# 103429    16000.0   60 months  ...       0.0                   0.0
# 103430     7925.0   36 months  ...       7.0                   0.0
# 103431    12000.0   36 months  ...       2.0                   0.0
# 103432    10000.0   36 months  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
df2['issue_d']= pd.DatetimeIndex(df['issue_d'])

# %%
df2.term.replace({' 36 months':36 , ' 60 months':60}, inplace=True)
df2
# Out:
#         loan_amnt  term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0    36  ...       0.0                   0.0
# 1          8000.0    36  ...       3.0                   0.0
# 2         15600.0    36  ...       0.0                   0.0
# 3          7200.0    36  ...       0.0                   0.0
# 4         24375.0    60  ...       1.0                   0.0
# ...           ...   ...  ...       ...                   ...
# 103428    32000.0    36  ...       2.0                   0.0
# 103429    16000.0    60  ...       0.0                   0.0
# 103430     7925.0    36  ...       7.0                   0.0
# 103431    12000.0    36  ...       2.0                   0.0
# 103432    10000.0    36  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
df2.sub_grade.sort_values().unique()
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
#        'G4', 'G5'], dtype=object)

# %%
df2.verification_status.unique()
# Out:
# array(['Not Verified', 'Source Verified', 'Verified'], dtype=object)

# %%
df2.verification_status.replace ({'Not Verified':-1, 'Source Verified':0, 'Verified':1},inplace= True)
df2
# Out:
#         loan_amnt  term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0    36  ...       0.0                   0.0
# 1          8000.0    36  ...       3.0                   0.0
# 2         15600.0    36  ...       0.0                   0.0
# 3          7200.0    36  ...       0.0                   0.0
# 4         24375.0    60  ...       1.0                   0.0
# ...           ...   ...  ...       ...                   ...
# 103428    32000.0    36  ...       2.0                   0.0
# 103429    16000.0    60  ...       0.0                   0.0
# 103430     7925.0    36  ...       7.0                   0.0
# 103431    12000.0    36  ...       2.0                   0.0
# 103432    10000.0    36  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
df2.sub_grade.replace({'A1':71, 'A2':72, 'A3':73, 'A4':74, 'A5':75, 'B1':61, 'B2':62, 'B3':63, 'B4':64, 'B5':65, 'C1':51,
       'C2':52, 'C3':53, 'C4':54, 'C5':55, 'D1':41, 'D2':42, 'D3':43, 'D4':44, 'D5':45, 'E1':31, 'E2':32,
       'E3':33, 'E4':34, 'E5':35, 'F1':21, 'F2':22, 'F3':23, 'F4':24, 'F5':25, 'G1':11, 'G2':12, 'G3':13,
       'G4':14, 'G5':15}, inplace= True)
df2
# Out:
#         loan_amnt  term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0    36  ...       0.0                   0.0
# 1          8000.0    36  ...       3.0                   0.0
# 2         15600.0    36  ...       0.0                   0.0
# 3          7200.0    36  ...       0.0                   0.0
# 4         24375.0    60  ...       1.0                   0.0
# ...           ...   ...  ...       ...                   ...
# 103428    32000.0    36  ...       2.0                   0.0
# 103429    16000.0    60  ...       0.0                   0.0
# 103430     7925.0    36  ...       7.0                   0.0
# 103431    12000.0    36  ...       2.0                   0.0
# 103432    10000.0    36  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
df2.application_type.unique()
# Out:
# array(['INDIVIDUAL', 'JOINT', 'DIRECT_PAY'], dtype=object)

# %%
df2.application_type.replace({'INDIVIDUAL':1, 'JOINT':2, 'DIRECT_PAY':3}, inplace=True)
df2
# Out:
#         loan_amnt  term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0    36  ...       0.0                   0.0
# 1          8000.0    36  ...       3.0                   0.0
# 2         15600.0    36  ...       0.0                   0.0
# 3          7200.0    36  ...       0.0                   0.0
# 4         24375.0    60  ...       1.0                   0.0
# ...           ...   ...  ...       ...                   ...
# 103428    32000.0    36  ...       2.0                   0.0
# 103429    16000.0    60  ...       0.0                   0.0
# 103430     7925.0    36  ...       7.0                   0.0
# 103431    12000.0    36  ...       2.0                   0.0
# 103432    10000.0    36  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
df2.emp_length.unique()
# Out:
# array(['10+ years', '4 years', '< 1 year', '6 years', '9 years',
#        '2 years', '3 years', '8 years', '7 years', '5 years', '1 year'],
#       dtype=object)

# %%
df2.emp_length.replace({'< 1 year':0,'1 year':1,'2 years':2, '3 years':3, '4 years':4, '5 years':5, '6 years':6, '7 years':7,'8 years':8, '9 years':9, '10+ years': 10}, inplace=True)

# %%
df2.initial_list_status.unique()
# Out:
# array(['w', 'f'], dtype=object)

# %%
df2.initial_list_status.replace({'w':0,'f':1},inplace=True)
df2
# Out:
#         loan_amnt  term  ...  mort_acc  pub_rec_bankruptcies
# 0         10000.0    36  ...       0.0                   0.0
# 1          8000.0    36  ...       3.0                   0.0
# 2         15600.0    36  ...       0.0                   0.0
# 3          7200.0    36  ...       0.0                   0.0
# 4         24375.0    60  ...       1.0                   0.0
# ...           ...   ...  ...       ...                   ...
# 103428    32000.0    36  ...       2.0                   0.0
# 103429    16000.0    60  ...       0.0                   0.0
# 103430     7925.0    36  ...       7.0                   0.0
# 103431    12000.0    36  ...       2.0                   0.0
# 103432    10000.0    36  ...       8.0                   0.0
#
# [87833 rows x 20 columns]

# %%
y= df2.loan_status == 'Charged Off'

# %%
df2.drop(columns = ['loan_status'],inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87833 entries, 0 to 103432
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             87833 non-null  float64
#  1   term                  87833 non-null  int64
#  2   int_rate              87833 non-null  float64
#  3   installment           87833 non-null  float64
#  4   sub_grade             87833 non-null  int64
#  5   emp_length            87833 non-null  int64
#  6   annual_inc            87833 non-null  float64
#  7   verification_status   87833 non-null  int64
#  8   issue_d               87833 non-null  datetime64[ns]
#  9   dti                   87833 non-null  float64
#  10  open_acc              87833 non-null  float64
#  11  pub_rec               87833 non-null  float64
#  12  revol_bal             87833 non-null  float64
#  13  revol_util            87833 non-null  float64
#  14  total_acc             87833 non-null  float64
#  15  initial_list_status   87833 non-null  int64
#  16  application_type      87833 non-null  int64
#  17  mort_acc              87833 non-null  float64
#  18  pub_rec_bankruptcies  87833 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(6)
# memory usage: 13.4 MB

# %%
visualize_cols=['loan_amnt','term','int_rate','installment','sub_grade','emp_length','verification_status','initial_list_status','application_type',
                'annual_inc','dti','open_acc',
                'pub_rec','revol_bal','revol_util', 
                'total_acc','mort_acc','pub_rec_bankruptcies']
plt.figure(figsize=(30,30))

for i in range(len(visualize_cols)):
    plt.subplot(5,5,i+1)
    sns.distplot(df2[visualize_cols[i]])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X= df2
classes= ['Fully Paid', 'Charged Off']

# %%
X[X.columns]= X[X.columns].apply(pd.to_numeric, errors='coerce')
X.dropna(axis=1, inplace=True)
visualizer= PCA(scale= True, classes= classes)
visualizer.fit_transform(X,y.values +1-1)
visualizer.show()
